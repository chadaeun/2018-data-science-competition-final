# %%
import pandas as pd
import ast
import nltk

# %% [markdown]
# # Load Data

# %%
def row_str_to_list(row):
    row['outreview'] = ' '.join(ast.literal_eval(row['outreview']))
    row['outtitle'] = ' '.join(ast.literal_eval(row['outtitle']))
    return row

# %%
data=pd.read_csv('data/multi/train.csv')
data = data.apply(row_str_to_list, axis=1)

# %%
data
# Out:
#                                          outtitle  \
# 0                                 wonderful dress
# 1                                      no brainer
# 2                                       nice tank
# 3                                            love
# 4                    vintage vibe builtin support
# 5                                      cute comfy
# 6      disappointed retailers descriptions lately
# 7                                 beautiful dress
# 8                                  swinging dress
# 9                                  gorgeous dress
# 10                                surprise winner
# 11                                       love top
# 12                             curvy girls beware
# 13                                  new summer go
# 14                                  perfect skirt
# 15                    gotten multiple compliments
# 16                                  darker person
# 17                                great basic tee
# 18                               fancy sweatshirt
# 19                                    love romper
# 20                             love texture color
# 21                                       nice top
# 22                                  disappointing
# 23                                      soft warm
# 24                                       gorgeous
# 25                                           love
# 26                                really nice top
# 27                                beautiful dress
# 28                                      stays put
# 29              love but pink blue not cream blue
# ...                                           ...
# 15710                                      le sac
# 15711                                 alter waist
# 15712                              cute dont size
# 15713                                         ugg
# 15714                                buy one size
# 15715                                         not
# 15716                                     dressed
# 15717                  beautiful detail loose fit
# 15718                                 missed mark
# 15719                                 great shape
# 15720                         gorgeous embroidery
# 15721                     pretty alterations whiz
# 15722                                  cute dress
# 15723                       cute details good cut
# 15724                                     amazing
# 15725                           perfect red cardi
# 15726                          truly unflattering
# 15727                                        love
# 15728                                   well made
# 15729                    looks nothing like photo
# 15730                  gorgeous white summer tank
# 15731                        even better pictured
# 15732             unexpected color fantastic coat
# 15733                    super cute wee bit small
# 15734       pretty but not good enough full price
# 15735                                        love
# 15736                             beautiful skirt
# 15737                               comfy classic
# 15738                                       comfy
# 15739                              runs big short
#
#                                                outreview  label
# 0      love dress think cut fabric embroidery flatter...      2
# 1      dress truly no brainer purchase stunning dress...      2
# 2      like look tank ran bit larger expected neck bu...      2
# 3      perfect end summer going fall soft pairs great...      2
# 4      good dress hourglass figures runs bit narrow r...      2
# 5      really love soft nice quality complaint straps...      2
# 6      one proved no different short end dress pretty...      0
# 7      beautiful dress delicately well made 51 95lb x...      2
# 8      thought dress store true size bit more swingin...      2
# 9      worse dress rehersal dinner received many comp...      2
# 10     tried store size but thought felt tight but pe...      2
# 11     picture wasnt sure would fit got mail love fit...      2
# 12     dress beautiful color fabric super soft lovely...      1
# 13                jumper cute soft dress depending going      2
# 14     love colors skirt wear tee flat sandals black ...      2
# 15     dont usually wear much color but im glad purch...      2
# 16     got skirt mail today overall im happy keep dis...      2
# 17     got color listed pink not usual pink fit goodn...      2
# 18     beautiful long midi blazer happens feel like s...      2
# 19     first romper purchased cute small medium usual...      2
# 20     love texture color tunic seem run large could ...      2
# 21     like reviewers experienced received top mail n...      2
# 22     expecting tunic bit structure weight layer leg...      1
# 23     like contrast skirt bodice length sleeves adn ...      2
# 24     most beautiful top closet huge closet beautifu...      2
# 25     im pregnant 2nd trimester really wanted beauti...      2
# 26     really love top great colors comfortable long ...      2
# 27     actually bought dress last year made another o...      2
# 28     classic design nice details stays place active...      2
# 29     heads didnt notice pink blue motif print arriv...      2
# ...                                                  ...    ...
# 15710  struggling find nice flowy summer dress isnt t...      0
# 15711  53 2838 ordered regular left way came would lo...      2
# 15712  cute shirt thought model would big sized more ...      2
# 15713  skirt gianormous usually take xl l ordered wai...      0
# 15714  love shirt bought shirt returning shirt believ...      2
# 15715  obsessed dress moment saw online excited buy c...      1
# 15716  looked reviews purchasing one time didnt work ...      2
# 15717  loved fabric details cut tad looserbigger expe...      1
# 15718  online dress looks perfect but person bit dowd...      1
# 15719  loved shape basic jacket perfect go yoga dress...      2
# 15720  purchased dress regular size small soon saw po...      2
# 15721  gorgeous sleeves flattering necklineand volumi...      1
# 15722  got wear beach vacation later august hesitant ...      2
# 15723  im sucker lace details dress otherwise plain w...      2
# 15724  fell love jumpsuit first sight color stunning ...      2
# 15725  wish list but saw black fridayand happened sis...      2
# 15726  granted not reed thin young model but tall rea...      0
# 15727  shirt great person online substantial fabric n...      2
# 15728  jacket looks great well made material lush how...      1
# 15729  poorly made wide short unflattering material a...      0
# 15730  got white surprised see fits petite but 32d bu...      2
# 15731  shirt beautiful fits perfectly soft too didnt ...      2
# 15732  bought 20 off sale made even more worth price ...      2
# 15733  im loving even wee bit tight im 56 130 lbs hit...      2
# 15734  thought dress lovely im 810 tried med believe ...      2
# 15735  love dress color quality design great sizing t...      2
# 15736  agree reviewer skirt beautiful print combed co...      2
# 15737  love sweater wish sized little longer length b...      2
# 15738  comfy dresstunic like wear leggings washed wel...      2
# 15739  dress shorter looks model im 58 hits 1 inch kn...      2
#
# [15740 rows x 3 columns]

# %% [markdown]
# # Compute Frequency
#
# 데이터 간 빈도 상위 단어 차이를 분석합니다.

# %%
def get_freqdist(series):
    """
    Get FreqDist from pandas Series
    """
    words = []
    
    for text in series:
        words.extend(text.split())
        
    return nltk.FreqDist(words)

# %%
def freqdist_to_table(freqdist):
    df = pd.DataFrame.from_dict(freqdist, orient='index')
    df.columns = ['frequency']
    df['percentage'] = df['frequency'] / df['frequency'].sum()
    return df.sort_values('frequency', ascending=False)[:10]

# %% [markdown]
# ## 전체 상위 빈도 단어

# %%
total = get_freqdist(data['outreview']) + get_freqdist(data['outtitle'])
freqdist_to_table(total)
# Out:
#        frequency  percentage
# but        12883    0.023510
# dress       8768    0.016000
# not         7698    0.014048
# love        7598    0.013865
# size        6429    0.011732
# top         6060    0.011059
# fit         5666    0.010340
# great       5599    0.010217
# like        5242    0.009566
# too         4703    0.008582

# %% [markdown]
# ## 리뷰 유형별 상위 빈도 단어 비교

# %%
neg_df = data[data['label'] == 0]
neg = get_freqdist(neg_df['outtitle']) + get_freqdist(neg_df['outreview'])
freqdist_to_table(neg)
# Out:
#         frequency  percentage
# but          1516    0.025927
# not          1256    0.021481
# dress         860    0.014708
# like          802    0.013716
# too           656    0.011219
# top           617    0.010552
# fit           586    0.010022
# fabric        548    0.009372
# would         512    0.008756
# size          504    0.008620

# %%
neu_df = data[data['label'] == 1]
neu = get_freqdist(neu_df['outtitle']) + get_freqdist(neu_df['outreview'])
freqdist_to_table(neu)
# Out:
#         frequency  percentage
# but          2338    0.031567
# not          1513    0.020428
# dress        1108    0.014960
# too           999    0.013488
# top           882    0.011909
# like          869    0.011733
# fit           861    0.011625
# size          750    0.010126
# would         673    0.009087
# fabric        663    0.008952

# %%
pos_df = data[data['label'] == 2]
pos = get_freqdist(pos_df['outtitle']) + get_freqdist(pos_df['outreview'])
freqdist_to_table(pos)
# Out:
#        frequency  percentage
# but         9029    0.021733
# dress       6800    0.016368
# love        6622    0.015939
# size        5175    0.012456
# great       4976    0.011977
# not         4929    0.011864
# top         4561    0.010978
# fit         4219    0.010155
# wear        3872    0.009320
# like        3571    0.008595

# %% [markdown]
# ## 제목 / 리뷰 별 상위 빈도 단어 비교

# %%
title = get_freqdist(data['outtitle'])
freqdist_to_table(title)
# Out:
#            frequency  percentage
# love            1473    0.036302
# great           1417    0.034922
# dress           1331    0.032803
# but             1234    0.030412
# cute            1226    0.030215
# beautiful       1102    0.027159
# top              914    0.022526
# not              817    0.020135
# perfect          644    0.015871
# pretty           532    0.013111

# %%
review = get_freqdist(data['outreview'])
freqdist_to_table(review)
# Out:
#        frequency  percentage
# but        11649    0.022958
# dress       7437    0.014657
# not         6881    0.013561
# size        6268    0.012353
# love        6125    0.012071
# fit         5184    0.010217
# top         5146    0.010142
# like        5041    0.009935
# wear        4526    0.008920
# too         4320    0.008514

# %% [markdown]
# ## 테스트 데이터 별 상위 빈도 단어 비교

# %%
cosmetic_df = pd.read_csv('data/binary/cosmetic.csv').apply(row_str_to_list, axis=1)
cosmetic = get_freqdist(cosmetic_df['outtitle']) + get_freqdist(cosmetic_df['outreview'])
freqdist_to_table(cosmetic)
# Out:
#          frequency  percentage
# sephora        272    0.019004
# but            189    0.013205
# makeup         166    0.011598
# store          147    0.010270
# not            147    0.010270
# like           127    0.008873
# one            106    0.007406
# love           101    0.007057
# help            92    0.006428
# dont            90    0.006288

# %%
food_df = pd.read_csv('data/binary/food.csv').apply(row_str_to_list, axis=1)
food = get_freqdist(food_df['outtitle']) + get_freqdist(food_df['outreview'])
freqdist_to_table(food)
# Out:
#          frequency  percentage
# karaoke        551    0.018615
# but            418    0.014122
# food           339    0.011453
# room           316    0.010676
# place          287    0.009696
# good           278    0.009392
# not            252    0.008514
# sushi          244    0.008244
# rooms          236    0.007973
# yamasho        201    0.006791

# %%
man_df = pd.read_csv('data/binary/man.csv').apply(row_str_to_list, axis=1)
man = get_freqdist(man_df['outtitle']) + get_freqdist(man_df['outreview'])
freqdist_to_table(man)
# Out:
#          frequency  percentage
# shirt          692    0.033126
# shirts         586    0.028052
# fit            398    0.019052
# proper         292    0.013978
# cloth          289    0.013834
# great          267    0.012781
# but            193    0.009239
# service        190    0.009095
# get            186    0.008904
# not            171    0.008186

# %%
woman_df = pd.read_csv('data/binary/woman.csv').apply(row_str_to_list, axis=1)
woman = get_freqdist(woman_df['outtitle']) + get_freqdist(woman_df['outreview'])
freqdist_to_table(woman)
# Out:
#          frequency  percentage
# but            182    0.016420
# store          158    0.014255
# primark        117    0.010556
# clothes        105    0.009473
# not            101    0.009112
# quality         96    0.008661
# like            83    0.007488
# place           77    0.006947
# cheap           74    0.006676
# great           70    0.006315
